# %%
# %pip install requests

# %%
import os
import requests

# %%
os.environ['BRAWLSTARS_TOKEN'] = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..xQiTT2rr43d3uk-jKmPtlna57A_F-XXY_ZsKCh7apm9a6gAqih6FerjzS5JCzw2zpGaGjPRDj0DA8pCmWQQEyw'

# %% [markdown]
# Helper function

# %%
import os, requests

def brawlstars_get(endpoint: str, params: dict = None) -> dict:
    token = os.environ.get('BRAWLSTARS_TOKEN')
    if not token:
        raise RuntimeError("BRAWLSTARS_TOKEN not set in environment")
    headers = {
        'Authorization': f"Bearer {token}",
        'Accept': 'application/json',
        'User-Agent': 'ColabBrawlClient/1.0'
    }
    resp = requests.get('https://api.brawlstars.com' + endpoint,
                        headers=headers, params=params)
    resp.raise_for_status()
    return resp.json()

# %%
player_tag = '%239PJCYYUO'

profile = brawlstars_get(f'/v1/players/{player_tag}')
battlelog = brawlstars_get(f'/v1/players/{player_tag}/battlelog')

# Join everything on a single json
player_data = {
    'profile': profile,
    'battlelog': battlelog
}
print(player_data)

# Download json
import json
with open('player_data.json', 'w') as f:
    json.dump(player_data, f)
# Out:
# {'profile': {'tag': '#9PJCYYUO', 'name': 'HUGOL tu padre', 'nameColor': '0xfff05637', 'icon': {'id': 28000848}, 'trophies': 26225, 'highestTrophies': 26225, 'expLevel': 133, 'expPoints': 92313, 'isQualifiedFromChampionshipChallenge': False, '3vs3Victories': 3565, 'soloVictories': 782, 'duoVictories': 395, 'bestRoboRumbleTime': 5, 'bestTimeAsBigBrawler': 0, 'club': {'tag': '#GGJJRRLG', 'name': 'tacos 🌮🌮'}, 'brawlers': [{'id': 16000000, 'name': 'SHELLY', 'power': 8, 'rank': 29, 'trophies': 527, 'highestTrophies': 562, 'gears': [], 'starPowers': [], 'gadgets': [{'id': 23000255, 'name': 'FAST FORWARD'}]}, {'id': 16000001, 'name': 'COLT', 'power': 9, 'rank': 27, 'trophies': 500, 'highestTrophies': 525, 'gears': [], 'starPowers': [{'id': 23000077, 'name': 'SLICK BOOTS'}, {'id': 23000138, 'name': 'MAGNUM SPECIAL'}], 'gadgets': [{'id': 23000273, 'name': 'SPEEDLOADER'}, {'id': 23000319, 'name': 'SILVER BULLET'}]}, {'id': 16000002, 'name': 'BULL', 'power': 8, 'rank': 29, 'trophies': 500, 'high
# ...
